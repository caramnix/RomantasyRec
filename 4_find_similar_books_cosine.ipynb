# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# read in full (cleaned) book list
full_book_list= pd.read_csv("/Users/caranix/Documents/GitHub/RomantasyRec/cleaned_romantasy_data.csv")

# read in favorite book list 
fav_book_list= pd.read_csv("user_read_list_fantasy_romance_titles_authors.csv")
fav_book_list= fav_book_list[fav_book_list['Rating_x'] >= 4]

# %%
# now we TF-IDF weight!
vectorizer = TfidfVectorizer(stop_words='english')

# Combine title, author, and description into a single feature
full_book_list['combined_features'] = full_book_list['cleaned_title'] + " " + full_book_list['cleaned_author'] + " " + full_book_list['cleaned_description']
fav_book_list['combined_features'] = fav_book_list['cleaned_title_y'] + " " + fav_book_list['cleaned_author_y'] + " " + fav_book_list['cleaned_description']


# Fit TF-IDF on all books and transform both datasets
tfidf_matrix_all = vectorizer.fit_transform(full_book_list['combined_features'])
tfidf_matrix_favs = vectorizer.transform(fav_book_list['combined_features'])

# %%
fav_book_list.head()
# Out:
#           Title_x               Author  Rating_x cleaned_title_x  \
# 1   Electric Idol        Katee  Robert       5.0   Electric Idol
# 3      The Ex Hex        Erin Sterling       5.0      The Ex Hex
# 4  A Game of Fate  Scarlett  St. Clair       5.0  A Game of Fate
# 6   The Selection          Kiera  Cass       5.0   The Selection
# 7          Cinder       Marissa  Meyer       4.0          Cinder
#
#      cleaned_author_x                                                api  \
# 1       Katee  Robert  https://www.googleapis.com/books/v1/volumes?q=...
# 3       Erin Sterling  https://www.googleapis.com/books/v1/volumes?q=...
# 4  Scarlett  St Clair  https://www.googleapis.com/books/v1/volumes?q=...
# 6         Kiera  Cass  https://www.googleapis.com/books/v1/volumes?q=...
# 7      Marissa  Meyer  https://www.googleapis.com/books/v1/volumes?q=...
#
#           Title_y cleaned_title_y   cleaned_author_y  Rating_y  \
# 1   Electric Idol   electric idol       katee robert      3.95
# 3      The Ex Hex          ex hex      erin sterling      3.48
# 4  A Game of Fate       game fate  scarlett st clair      4.00
# 6   The Selection       selection         kiera cass      4.08
# 7          Cinder          cinder      marissa meyer      4.13
#
#   Count of Ratings                                cleaned_description  \
# 1          111,306  instant new york time usa today bestseller bea...
# 3          248,969  new york time bestseller erin sterling cast de...
# 4           84,809  discover enthralling fantasy world god mortal ...
# 6        1,661,933  fall lovefrom beginning discover first book ca...
# 7          970,130  new york time bestselling series human android...
#
#   cleaned_publisher cleaned_page_count_v1  cleaned_count_ratings_v1  \
# 1             other                  <300                       2.0
# 3    harper collins                  <300                       1.0
# 4             other               300-450                       2.0
# 6    harper collins               300-450                       1.0
# 7             other               300-450                       1.0
#
#    published_year  mature                                  combined_features
# 1          2022.0     1.0  electric idol katee robert instant new york ti...
# 3          2021.0     1.0  ex hex erin sterling new york time bestseller ...
# 4          2021.0     1.0  game fate scarlett st clair discover enthralli...
# 6          2012.0     0.0  selection kiera cass fall lovefrom beginning d...
# 7          2012.0     0.0  cinder marissa meyer new york time bestselling...

# %%
# compute cosine similarity!! 

cosine_similarities = cosine_similarity(tfidf_matrix_favs, tfidf_matrix_all)

# %%
fav_indices = np.where(full_book_list['Title'].isin(fav_book_list['Title_x']))[0].tolist()

# %%
read_book_list= pd.read_csv("user_read_list_fantasy_romance_titles_authors.csv")
read_indices = np.where(full_book_list['Title'].isin(fav_book_list['Title_x']))[0].tolist()

# %%
full_book_list.iloc[216]
# Out:
# api                         https://www.googleapis.com/books/v1/volumes?q=...
# Title                                                           Electric Idol
# cleaned_title                                                   electric idol
# cleaned_author                                                   katee robert
# Rating                                                                   3.95
# Count of Ratings                                                      111,306
# cleaned_description         instant new york time usa today bestseller bea...
# cleaned_publisher                                                       other
# cleaned_page_count_v1                                                    <300
# cleaned_count_ratings_v1                                                    2
# published_year                                                         2022.0
# mature                                                                      1
# combined_features           electric idol katee robert instant new york ti...
# Name: 216, dtype: object

# %%
np.argsort(cosine_similarities[0], axis=0)[-2]
# Out:
# np.int64(60)

# %%
cosine_similarities[0][60]
# Out:
# np.float64(0.4395013372221967)

# %%
np.argsort(cosine_similarities[0], axis=0)
# s0 smallest value is at index 683, largest is at 216
# Out:
# array([683, 955,  85, ..., 417,  60, 216])

# %%
d= {} # key: index in  , value: 
for i in range(len(cosine_similarities)): 
    index_to_access = -2
    no_match = True 
    while no_match: 
        idx_top_rec= np.argsort(cosine_similarities[i], axis=0)[index_to_access] # exclude self 
        if idx_top_rec in read_indices: #if we've already read it, pick next top match! 
            index_to_access = index_to_access - 1
        else: 
            if idx_top_rec not in d.keys(): 
                closest_match_book_info= full_book_list.iloc[idx_top_rec]
                title= closest_match_book_info['Title']
                author= closest_match_book_info['cleaned_author']
                cosine_sim_score_for_closest_match= cosine_similarities[i][idx_top_rec]

                d[idx_top_rec] = {"title" : title, "author": author, "cosine_sim" : cosine_sim_score_for_closest_match, "ct" : 1, "index": idx_top_rec}
               
            else: 
                 cosine_sim_score_for_closest_match= cosine_similarities[i][idx_top_rec]
                 d[idx_top_rec]['ct'] +=1 
                 d[idx_top_rec]['cosine_sim'] +=cosine_sim_score_for_closest_match 

            no_match = False
            
# goal is to return top similar book name, author + score!

# %%
rec_df= pd.json_normalize(d.values())

# %%
rec_df.sort_values(by=['ct','cosine_sim'], ascending=[False, False])
# Out:
#                                title                 author  cosine_sim  ct  \
# 15                 Crown of Midnight           sarah j maas    1.148831   5
# 27         A Court of Wings and Ruin           sarah j maas    1.127161   4
# 6                    Ruin and Rising          leigh bardugo    1.448027   2
# 0                      Wicked Beauty           katee robert    0.883197   2
# 7                            Defy Me           tahereh mafi    0.702258   2
# 3                          The Elite             kiera cass    0.702132   1
# 8                       Ruthless Fae       caroline peckham    0.611878   1
# 5                         Destroy Me           tahereh mafi    0.574406   1
# 2              A Game of Retribution      scarlett st clair    0.531567   1
# 14                      Midnight Sun        stephenie meyer    0.513728   1
# 13                         War Storm       victoria aveyard    0.447226   1
# 22           Children of Fallen Gods      carissa broadbent    0.412901   1
# 23                    Kingdom of Ash           sarah j maas    0.358768   1
# 9                   Clockwork Prince        cassandra clare    0.358165   1
# 4                            Scarlet          marissa meyer    0.349509   1
# 11                City of Lost Souls        cassandra clare    0.343679   1
# 24  The Assassin and the Pirate Lord           sarah j maas    0.320937   1
# 25                       Fourth Wing         rebecca yarros    0.274367   1
# 1                     The Kiss Curse          erin sterling    0.251996   1
# 10                         Powerless          lauren robert    0.246031   1
# 18       Origins of an Academy Bully       caroline peckham    0.231425   1
# 26                     Fortuna Sworn              kj sutton    0.219250   1
# 12             Born of Blood and Ash  jennifer l armentrout    0.216048   1
# 20            Mother of Death & Dawn      carissa broadbent    0.192976   1
# 16        Land of the Beautiful Dead            r lee smith    0.143959   1
# 21                            Marked                pc cast    0.124127   1
# 19                         Crescendo      becca fitzpatrick    0.123717   1
# 17                  Bryony and Roses             kingfisher    0.119246   1
#
#     index
# 15     16
# 27      3
# 6     208
# 0     417
# 7     306
# 3     371
# 8      89
# 5     336
# 2     445
# 14    325
# 13    433
# 22    151
# 23     31
# 9     224
# 4     351
# 11    294
# 24    894
# 25      2
# 1     708
# 10     21
# 18    543
# 26    131
# 12    353
# 20    220
# 16    560
# 21    629
# 19    550
# 17    830
