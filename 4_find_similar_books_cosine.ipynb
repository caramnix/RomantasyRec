# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# read in full (cleaned) book list
full_book_list= pd.read_csv("/Users/caranix/Documents/GitHub/RomantasyRec/cleaned_romantasy_data.csv")

# %%
# read in favorite book list 
fav_book_list= pd.read_csv("user_read_list_fantasy_romance_titles_authors.csv")
fav_book_list= fav_book_list[fav_book_list['Rating_x'] >= 4]

# %%
# now we TF-IDF weight!
vectorizer = TfidfVectorizer(stop_words='english')

# Combine title, author, and description into a single feature
full_book_list['combined_features'] = full_book_list['cleaned_title'] + " " + full_book_list['cleaned_author'] + " " + full_book_list['cleaned_description']
fav_book_list['combined_features'] = fav_book_list['cleaned_title_y'] + " " + fav_book_list['cleaned_author_y'] + " " + fav_book_list['cleaned_description']


# Fit TF-IDF on all books and transform both datasets
tfidf_matrix_all = vectorizer.fit_transform(full_book_list['combined_features'])
tfidf_matrix_favs = vectorizer.transform(fav_book_list['combined_features'])

# %%
# compute cosine similarity!! 

cosine_similarities = cosine_similarity(tfidf_matrix_favs, tfidf_matrix_all)

# %%
fav_book_list
# Out:
#                              Title_x                   Author  Rating_x  \
# 1                      Electric Idol            Katee  Robert       5.0
# 3                         The Ex Hex            Erin Sterling       5.0
# 4                     A Game of Fate      Scarlett  St. Clair       5.0
# 6                      The Selection              Kiera  Cass       5.0
# 7                             Cinder           Marissa  Meyer       4.0
# 8                          Ignite Me             Tahereh Mafi       5.0
# 9                    Siege and Storm           Leigh  Bardugo       5.0
# 10                        Unravel Me             Tahereh Mafi       5.0
# 12                      Cursed Fates        Caroline  Peckham       4.0
# 14                   Clockwork Angel         Cassandra  Clare       5.0
# 15                          Reckless          Lauren  Roberts       4.0
# 17                     City of Bones         Cassandra  Clare       5.0
# 20            Fall of Ruin and Wrath  Jennifer L.  Armentrout       5.0
# 22                   Shadow and Bone           Leigh  Bardugo       5.0
# 23                         Red Queen        Victoria  Aveyard       4.0
# 24                        Shatter Me             Tahereh Mafi       5.0
# 25                          Twilight          Stephenie Meyer       4.0
# 26                         Neon Gods            Katee  Robert       5.0
# 27              The Assassin's Blade           Sarah J.  Maas       5.0
# 29                The Book of Azrael          Amber V  Nicole       5.0
# 31         House of Flame and Shadow           Sarah J.  Maas       4.0
# 32                     The Awakening        Caroline  Peckham       5.0
# 33                     The Awakening        Caroline  Peckham       5.0
# 34  The Ashes & the Star-Cursed King       Carissa  Broadbent       4.0
# 35                     Tower of Dawn           Sarah J.  Maas       5.0
# 36                             Bride           Ali  Hazelwood       5.0
# 37             Daughter of No Worlds       Carissa  Broadbent       4.0
# 38                  Empire of Storms           Sarah J.  Maas       5.0
# 39                  Queen of Shadows           Sarah J.  Maas       5.0
# 41                      Heir of Fire           Sarah J.  Maas       5.0
# 42           House of Sky and Breath           Sarah J.  Maas       5.0
# 45                   Throne of Glass           Sarah J.  Maas       5.0
# 46                        Iron Flame          Rebecca  Yarros       5.0
# 47          House of Earth and Blood           Sarah J.  Maas       5.0
# 48    A Court of Frost and Starlight           Sarah J.  Maas       5.0
# 49          A Court of Silver Flames           Sarah J.  Maas       4.0
# 51          A Court of Mist and Fury           Sarah J.  Maas       5.0
# 52       A Court of Thorns and Roses           Sarah J.  Maas       5.0
#
#                      cleaned_title_x        cleaned_author_x  \
# 1                      Electric Idol           Katee  Robert
# 3                         The Ex Hex           Erin Sterling
# 3       A Court of Wings and Ruin   court wing ruin           sarah j maas
# 4              From Blood and Ash         blood ash  jennifer l armentrout
# ...                           ...               ...                    ...
# 1061            The Scorpio Races      scorpio race      maggie stiefvater
# 1062              Blaze of Memory      blaze memory           nalini singh
# 1063             Split or Swallow     split swallow        lindsay straube
# 1064       Autumn of the Grimoire   autumn grimoire               jl vampa
# 1065                Curious Tides      curious tide        pascale lacelle
#
#       Rating Count of Ratings  \
# 0       4.18        3,459,145
# 1       4.65        2,625,974
# 2       4.58        2,508,672
# 3       4.47        2,194,491
# 4       4.22          708,676
# ...      ...              ...
# 1061    4.10          111,812
# 1062    3.96           24,997
# 1063    3.83            5,662
# 1064    4.05            3,185
# 1065    3.81           10,090
#
#                                     cleaned_description cleaned_publisher  \
# 0     first instalment global phenomenon tiktok sens...        bloomsbury
# 1     new york time bestselling sequel sarah j maass...        bloomsbury
# 2     war grows deadly violet sorrengail join elite ...         entangled
# 3     feyre must decide trust among high lord turn a...        bloomsbury
# 4     captivating actionpacked blood ash sexy addict...             other
# ...                                                 ...               ...
# 1061  every november scorpio race run beneath chalk ...             other
# 1062  nalini singh return psychangeling world woman ...             other
# 1063  internet sensation amazon bestseller lindsay s...             other
# 1064  witch cast spell others slay king mysterious g...             other
# 1065  teen mage emory must unravel truth behind secr...             other
#
#      cleaned_page_count_v1  cleaned_count_ratings_v1  published_year  mature  \
# 0                     450+                         1          2020.0       0
# 1                     450+                         1          2017.0       0
# 2                     <300                         1          2023.0       0
# 3                     450+                         1          2017.0       0
# 4                  300-450                         1          2020.0       0
# ...                    ...                       ...             ...     ...
# 1061                  <300                         2          2022.0       0
# 1062               300-450                         5          2011.0       0
# 1063                  450+                         6          2025.0       0
# 1064               300-450                         6          2022.0       0
# 1065                  450+                         5          2024.0       0
#
#                                       combined_features
# 0     court thorn rose sarah j maas first instalment...
# 1     court mist fury sarah j maas new york time bes...
# 2     fourth wing rebecca yarros war grows deadly vi...
# 3     court wing ruin sarah j maas feyre must decide...
# 4     blood ash jennifer l armentrout captivating ac...
# ...                                                 ...
# 1061  scorpio race maggie stiefvater every november ...
# 1062  blaze memory nalini singh nalini singh return ...
# 1063  split swallow lindsay straube internet sensati...
# 1064  autumn grimoire jl vampa witch cast spell othe...
# 1065  curious tide pascale lacelle teen mage emory m...
#
# [1066 rows x 13 columns]

# %%
fav_indices = np.where(full_book_list['Title'].isin(fav_book_list['Title']))[0].tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/RomantasyRec/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 fav_indices = np.where(full_book_list['Title'].isin(fav_book_list['Title']))[0].tolist()
#
# File ~/anaconda3/envs/RomantasyRec/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/envs/RomantasyRec/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Title'

# %%
for i in range (len(cosine_similarities)): 
    index_to_access = -2 
    match = True 
    while match: 
        idx_top_rec= np.argsort(cosine_similarities[i], axis=0)[index_to_access] # exclude self 
        if idx_top_rec in *list of read books*: 
            index_to_access = index_to_access - 1
        else: 
            # this is the top match you want to return!

# %%
# for first fav book, cosine_similarities[0], cosine similarity between it and the other 1000 books

# %%
# get max reccomended that isn't (1) itself, and (2) in the list of all read books

# %%
# do this for all of the 38, then get highest values, rank those, no duplicates

# %%
cosine_similarities[0]
# Out:
# array([0])

# %%
np.argsort(cosine_similarities[0], axis=0)[-2]
# Out:
# np.int64(60)
